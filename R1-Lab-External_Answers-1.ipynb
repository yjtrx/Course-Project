# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
import numpy as np
x=pd.read_csv('Iris.csv')
Iris=pd.DataFrame(x)
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
type(Iris.iloc[:,:])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
Iris.head(n=10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
Iris.tail(n=10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.reset_index(inplace=True)

# %%
Iris.set_index(Iris['index'],inplace=True)

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2]
# Out:
# index
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 8      2.9
# 9      3.1
# 10     3.7
# 11     3.4
# 12     3.0
# 13     3.0
# 14     4.0
# 15     4.4
# 16     3.9
# 17     3.5
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 25     3.0
# 26     3.4
# 27     3.5
# 28     3.4
# 29     3.2
#       ...
# 120    3.2
# 121    2.8
# 122    2.8
# 123    2.7
# 124    3.3
# 125    3.2
# 126    2.8
# 127    3.0
# 128    2.8
# 129    3.0
# 130    2.8
# 131    3.8
# 132    2.8
# 133    2.8
# 134    2.6
# 135    3.0
# 136    3.4
# 137    3.1
# 138    3.0
# 139    3.1
# 140    3.1
# 141    3.1
# 142    2.7
# 143    3.2
# 144    3.3
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: Sepal Width in (cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.iloc[0:10,1:3]
# Out:
#        Sepal Length (in cm)  Sepal Width in (cm)
# index
# 0                       5.1                  3.5
# 1                       4.9                  3.0
# 2                       4.7                  3.2
# 3                       4.6                  3.1
# 4                       5.0                  3.6
# 5                       5.4                  3.9
# 6                       4.6                  3.4
# 7                       5.0                  3.4
# 8                       4.4                  2.9
# 9                       4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
x=Iris['Class']=='Iris-setosa'
Iris.where(x,inplace=True)
Iris.dropna()
# Out:
#        index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# index
# 0        0.0                   5.1                  3.5                   1.4
# 1        1.0                   4.9                  3.0                   1.4
# 2        2.0                   4.7                  3.2                   1.3
# 3        3.0                   4.6                  3.1                   1.5
# 4        4.0                   5.0                  3.6                   1.4
# 5        5.0                   5.4                  3.9                   1.7
# 6        6.0                   4.6                  3.4                   1.4
# 7        7.0                   5.0                  3.4                   1.5
# 8        8.0                   4.4                  2.9                   1.4
# 9        9.0                   4.9                  3.1                   1.5
# 10      10.0                   5.4                  3.7                   1.5
# 11      11.0                   4.8                  3.4                   1.6
# 12      12.0                   4.8                  3.0                   1.4
# 13      13.0                   4.3                  3.0                   1.1
# 14      14.0                   5.8                  4.0                   1.2
# 15      15.0                   5.7                  4.4                   1.5
# 16      16.0                   5.4                  3.9                   1.3
# 17      17.0                   5.1                  3.5                   1.4
# 18      18.0                   5.7                  3.8                   1.7
# 19      19.0                   5.1                  3.8                   1.5
# 20      20.0                   5.4                  3.4                   1.7
# 21      21.0                   5.1                  3.7                   1.5
# 22      22.0                   4.6                  3.6                   1.0
# 23      23.0                   5.1                  3.3                   1.7
# 24      24.0                   4.8                  3.4                   1.9
# 25      25.0                   5.0                  3.0                   1.6
# 26      26.0                   5.0                  3.4                   1.6
# 27      27.0                   5.2                  3.5                   1.5
# 28      28.0                   5.2                  3.4                   1.4
# 29      29.0                   4.7                  3.2                   1.6
# 30      30.0                   4.8                  3.1                   1.6
# 31      31.0                   5.4                  3.4                   1.5
# 32      32.0                   5.2                  4.1                   1.5
# 33      33.0                   5.5                  4.2                   1.4
# 34      34.0                   4.9                  3.1                   1.5
# 35      35.0                   5.0                  3.2                   1.2
# 36      36.0                   5.5                  3.5                   1.3
# 37      37.0                   4.9                  3.1                   1.5
# 38      38.0                   4.4                  3.0                   1.3
# 39      39.0                   5.1                  3.4                   1.5
# 40      40.0                   5.0                  3.5                   1.3
# 41      41.0                   4.5                  2.3                   1.3
# 42      42.0                   4.4                  3.2                   1.3
# 43      43.0                   5.0                  3.5                   1.6
# 44      44.0                   5.1                  3.8                   1.9
# 45      45.0                   4.8                  3.0                   1.4
# 46      46.0                   5.1                  3.8                   1.6
# 47      47.0                   4.6                  3.2                   1.4
# 48      48.0                   5.3                  3.7                   1.5
# 49      49.0                   5.0                  3.3                   1.4
#
#        Petal width (in cm)        Class
# index
# 0                      0.2  Iris-setosa
# 1                      0.2  Iris-setosa
# 2                      0.2  Iris-setosa
# 3                      0.2  Iris-setosa
# 4                      0.2  Iris-setosa
# 5                      0.4  Iris-setosa
# 6                      0.3  Iris-setosa
# 7                      0.2  Iris-setosa
# 8                      0.2  Iris-setosa
# 9                      0.1  Iris-setosa
# 10                     0.2  Iris-setosa
# 11                     0.2  Iris-setosa
# 12                     0.1  Iris-setosa
# 13                     0.1  Iris-setosa
# 14                     0.2  Iris-setosa
# 15                     0.4  Iris-setosa
# 16                     0.4  Iris-setosa
# 17                     0.3  Iris-setosa
# 18                     0.3  Iris-setosa
# 19                     0.3  Iris-setosa
# 20                     0.2  Iris-setosa
# 21                     0.4  Iris-setosa
# 22                     0.2  Iris-setosa
# 23                     0.5  Iris-setosa
# 24                     0.2  Iris-setosa
# 25                     0.2  Iris-setosa
# 26                     0.4  Iris-setosa
# 27                     0.2  Iris-setosa
# 28                     0.2  Iris-setosa
# 29                     0.2  Iris-setosa
# 30                     0.2  Iris-setosa
# 31                     0.4  Iris-setosa
# 32                     0.1  Iris-setosa
# 33                     0.2  Iris-setosa
# 34                     0.1  Iris-setosa
# 35                     0.2  Iris-setosa
# 36                     0.2  Iris-setosa
# 37                     0.1  Iris-setosa
# 38                     0.2  Iris-setosa
# 39                     0.2  Iris-setosa
# 40                     0.3  Iris-setosa
# 41                     0.3  Iris-setosa
# 42                     0.2  Iris-setosa
# 43                     0.6  Iris-setosa
# 44                     0.4  Iris-setosa
# 45                     0.3  Iris-setosa
# 46                     0.2  Iris-setosa
# 47                     0.2  Iris-setosa
# 48                     0.2  Iris-setosa
# 49                     0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra']= Iris['Sepal Length (in cm)']  * Iris['Sepal Width in (cm)']

# %%
Iris
# Out:
#        index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# index
# 0        0.0                   5.1                  3.5                   1.4
# 1        1.0                   4.9                  3.0                   1.4
# 2        2.0                   4.7                  3.2                   1.3
# 3        3.0                   4.6                  3.1                   1.5
# 4        4.0                   5.0                  3.6                   1.4
# 5        5.0                   5.4                  3.9                   1.7
# 6        6.0                   4.6                  3.4                   1.4
# 7        7.0                   5.0                  3.4                   1.5
# 8        8.0                   4.4                  2.9                   1.4
# 9        9.0                   4.9                  3.1                   1.5
# 10      10.0                   5.4                  3.7                   1.5
# 11      11.0                   4.8                  3.4                   1.6
# 12      12.0                   4.8                  3.0                   1.4
# 13      13.0                   4.3                  3.0                   1.1
# 14      14.0                   5.8                  4.0                   1.2
# 15      15.0                   5.7                  4.4                   1.5
# 16      16.0                   5.4                  3.9                   1.3
# 17      17.0                   5.1                  3.5                   1.4
# 18      18.0                   5.7                  3.8                   1.7
# 19      19.0                   5.1                  3.8                   1.5
# 20      20.0                   5.4                  3.4                   1.7
# 21      21.0                   5.1                  3.7                   1.5
# 22      22.0                   4.6                  3.6                   1.0
# 23      23.0                   5.1                  3.3                   1.7
# 24      24.0                   4.8                  3.4                   1.9
# 25      25.0                   5.0                  3.0                   1.6
# 26      26.0                   5.0                  3.4                   1.6
# 27      27.0                   5.2                  3.5                   1.5
# 28      28.0                   5.2                  3.4                   1.4
# 29      29.0                   4.7                  3.2                   1.6
# ...      ...                   ...                  ...                   ...
# 120      NaN                   NaN                  NaN                   NaN
# 121      NaN                   NaN                  NaN                   NaN
# 122      NaN                   NaN                  NaN                   NaN
# 123      NaN                   NaN                  NaN                   NaN
# 124      NaN                   NaN                  NaN                   NaN
# 125      NaN                   NaN                  NaN                   NaN
# 126      NaN                   NaN                  NaN                   NaN
# 127      NaN                   NaN                  NaN                   NaN
# 128      NaN                   NaN                  NaN                   NaN
# 129      NaN                   NaN                  NaN                   NaN
# 130      NaN                   NaN                  NaN                   NaN
# 131      NaN                   NaN                  NaN                   NaN
# 132      NaN                   NaN                  NaN                   NaN
# 133      NaN                   NaN                  NaN                   NaN
# 134      NaN                   NaN                  NaN                   NaN
# 135      NaN                   NaN                  NaN                   NaN
# 136      NaN                   NaN                  NaN                   NaN
# 137      NaN                   NaN                  NaN                   NaN
# 138      NaN                   NaN                  NaN                   NaN
# 139      NaN                   NaN                  NaN                   NaN
# 140      NaN                   NaN                  NaN                   NaN
# 141      NaN                   NaN                  NaN                   NaN
# 142      NaN                   NaN                  NaN                   NaN
# 143      NaN                   NaN                  NaN                   NaN
# 144      NaN                   NaN                  NaN                   NaN
# 145      NaN                   NaN                  NaN                   NaN
# 146      NaN                   NaN                  NaN                   NaN
# 147      NaN                   NaN                  NaN                   NaN
# 148      NaN                   NaN                  NaN                   NaN
# 149      NaN                   NaN                  NaN                   NaN
#
#        Petal width (in cm)        Class  SepalExtra
# index
# 0                      0.2  Iris-setosa       17.85
# 1                      0.2  Iris-setosa       14.70
# 2                      0.2  Iris-setosa       15.04
# 3                      0.2  Iris-setosa       14.26
# 4                      0.2  Iris-setosa       18.00
# 5                      0.4  Iris-setosa       21.06
# 6                      0.3  Iris-setosa       15.64
# 7                      0.2  Iris-setosa       17.00
# 8                      0.2  Iris-setosa       12.76
# 9                      0.1  Iris-setosa       15.19
# 10                     0.2  Iris-setosa       19.98
# 11                     0.2  Iris-setosa       16.32
# 12                     0.1  Iris-setosa       14.40
# 13                     0.1  Iris-setosa       12.90
# 14                     0.2  Iris-setosa       23.20
# 15                     0.4  Iris-setosa       25.08
# 16                     0.4  Iris-setosa       21.06
# 17                     0.3  Iris-setosa       17.85
# 18                     0.3  Iris-setosa       21.66
# 19                     0.3  Iris-setosa       19.38
# 20                     0.2  Iris-setosa       18.36
# 21                     0.4  Iris-setosa       18.87
# 22                     0.2  Iris-setosa       16.56
# 23                     0.5  Iris-setosa       16.83
# 24                     0.2  Iris-setosa       16.32
# 25                     0.2  Iris-setosa       15.00
# 26                     0.4  Iris-setosa       17.00
# 27                     0.2  Iris-setosa       18.20
# 28                     0.2  Iris-setosa       17.68
# 29                     0.2  Iris-setosa       15.04
# ...                    ...          ...         ...
# 120                    NaN          NaN         NaN
# 121                    NaN          NaN         NaN
# 122                    NaN          NaN         NaN
# 123                    NaN          NaN         NaN
# 124                    NaN          NaN         NaN
# 125                    NaN          NaN         NaN
# 126                    NaN          NaN         NaN
# 127                    NaN          NaN         NaN
# 128                    NaN          NaN         NaN
# 129                    NaN          NaN         NaN
# 130                    NaN          NaN         NaN
# 131                    NaN          NaN         NaN
# 132                    NaN          NaN         NaN
# 133                    NaN          NaN         NaN
# 134                    NaN          NaN         NaN
# 135                    NaN          NaN         NaN
# 136                    NaN          NaN         NaN
# 137                    NaN          NaN         NaN
# 138                    NaN          NaN         NaN
# 139                    NaN          NaN         NaN
# 140                    NaN          NaN         NaN
# 141                    NaN          NaN         NaN
# 142                    NaN          NaN         NaN
# 143                    NaN          NaN         NaN
# 144                    NaN          NaN         NaN
# 145                    NaN          NaN         NaN
# 146                    NaN          NaN         NaN
# 147                    NaN          NaN         NaN
# 148                    NaN          NaN         NaN
# 149                    NaN          NaN         NaN
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris.mean()
# Out:
# index                   24.5000
# Sepal Length (in cm)     5.0060
# Sepal Width in (cm)      3.4180
# Petal length (in cm)     1.4640
# Petal width (in cm)      0.2440
# SepalExtra              17.2088
# dtype: float64

# %%
Iris.var()
# Out:
# index                   212.500000
# Sepal Length (in cm)      0.124249
# Sepal Width in (cm)       0.145180
# Petal length (in cm)      0.030106
# Petal width (in cm)       0.011494
# SepalExtra                8.688864
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def take2input(x,y):
    print("The first no. is :",x )
    print("The Second no. is :",y)
    
z=take2input(5,3.6)
# Out:
# The first no. is : 5
# The Second no. is : 3.6

# %%
def taketwoinputs():
    x=input("Please enter your 1st no.")
    y=input("Please enter your 2nd no.")
    print("This is the 1st no:",x + " "+ "& this is the 2nd no.",y)

# %%
 z=taketwoinputs()
# Out:
# Please enter your 1st no.5
# Please enter your 2nd no.3.6
# This is the 1st no: 5 & this is the 2nd no. 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
a=Iris.max()
a
# Out:
# index                   49.00
# Sepal Length (in cm)     5.80
# Sepal Width in (cm)      4.40
# Petal length (in cm)     1.90
# Petal width (in cm)      0.60
# SepalExtra              25.08
# dtype: float64

# %%
b=Iris.min()
b
# Out:
# index                    0.00
# Sepal Length (in cm)     4.30
# Sepal Width in (cm)      2.30
# Petal length (in cm)     1.00
# Petal width (in cm)      0.10
# SepalExtra              10.35
# dtype: float64

# %%
a-b
# Out:
# index                   49.00
# Sepal Length (in cm)     1.50
# Sepal Width in (cm)      2.10
# Petal length (in cm)     0.90
# Petal width (in cm)      0.50
# SepalExtra              14.73
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values('Petal width (in cm)', axis =0)
# Out:
#        index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# index
# 34      34.0                   4.9                  3.1                   1.5
# 37      37.0                   4.9                  3.1                   1.5
# 32      32.0                   5.2                  4.1                   1.5
# 13      13.0                   4.3                  3.0                   1.1
# 9        9.0                   4.9                  3.1                   1.5
# 12      12.0                   4.8                  3.0                   1.4
# 25      25.0                   5.0                  3.0                   1.6
# 27      27.0                   5.2                  3.5                   1.5
# 28      28.0                   5.2                  3.4                   1.4
# 29      29.0                   4.7                  3.2                   1.6
# 30      30.0                   4.8                  3.1                   1.6
# 0        0.0                   5.1                  3.5                   1.4
# 48      48.0                   5.3                  3.7                   1.5
# 35      35.0                   5.0                  3.2                   1.2
# 36      36.0                   5.5                  3.5                   1.3
# 38      38.0                   4.4                  3.0                   1.3
# 39      39.0                   5.1                  3.4                   1.5
# 42      42.0                   4.4                  3.2                   1.3
# 46      46.0                   5.1                  3.8                   1.6
# 47      47.0                   4.6                  3.2                   1.4
# 33      33.0                   5.5                  4.2                   1.4
# 22      22.0                   4.6                  3.6                   1.0
# 24      24.0                   4.8                  3.4                   1.9
# 7        7.0                   5.0                  3.4                   1.5
# 1        1.0                   4.9                  3.0                   1.4
# 2        2.0                   4.7                  3.2                   1.3
# 3        3.0                   4.6                  3.1                   1.5
# 4        4.0                   5.0                  3.6                   1.4
# 8        8.0                   4.4                  2.9                   1.4
# 10      10.0                   5.4                  3.7                   1.5
# ...      ...                   ...                  ...                   ...
# 120      NaN                   NaN                  NaN                   NaN
# 121      NaN                   NaN                  NaN                   NaN
# 122      NaN                   NaN                  NaN                   NaN
# 123      NaN                   NaN                  NaN                   NaN
# 124      NaN                   NaN                  NaN                   NaN
# 125      NaN                   NaN                  NaN                   NaN
# 126      NaN                   NaN                  NaN                   NaN
# 127      NaN                   NaN                  NaN                   NaN
# 128      NaN                   NaN                  NaN                   NaN
# 129      NaN                   NaN                  NaN                   NaN
# 130      NaN                   NaN                  NaN                   NaN
# 131      NaN                   NaN                  NaN                   NaN
# 132      NaN                   NaN                  NaN                   NaN
# 133      NaN                   NaN                  NaN                   NaN
# 134      NaN                   NaN                  NaN                   NaN
# 135      NaN                   NaN                  NaN                   NaN
# 136      NaN                   NaN                  NaN                   NaN
# 137      NaN                   NaN                  NaN                   NaN
# 138      NaN                   NaN                  NaN                   NaN
# 139      NaN                   NaN                  NaN                   NaN
# 140      NaN                   NaN                  NaN                   NaN
# 141      NaN                   NaN                  NaN                   NaN
# 142      NaN                   NaN                  NaN                   NaN
# 143      NaN                   NaN                  NaN                   NaN
# 144      NaN                   NaN                  NaN                   NaN
# 145      NaN                   NaN                  NaN                   NaN
# 146      NaN                   NaN                  NaN                   NaN
# 147      NaN                   NaN                  NaN                   NaN
# 148      NaN                   NaN                  NaN                   NaN
# 149      NaN                   NaN                  NaN                   NaN
#
#        Petal width (in cm)        Class  SepalExtra
# index
# 34                     0.1  Iris-setosa       15.19
# 37                     0.1  Iris-setosa       15.19
# 32                     0.1  Iris-setosa       21.32
# 13                     0.1  Iris-setosa       12.90
# 9                      0.1  Iris-setosa       15.19
# 12                     0.1  Iris-setosa       14.40
# 25                     0.2  Iris-setosa       15.00
# 27                     0.2  Iris-setosa       18.20
# 28                     0.2  Iris-setosa       17.68
# 29                     0.2  Iris-setosa       15.04
# 30                     0.2  Iris-setosa       14.88
# 0                      0.2  Iris-setosa       17.85
# 48                     0.2  Iris-setosa       19.61
# 35                     0.2  Iris-setosa       16.00
# 36                     0.2  Iris-setosa       19.25
# 38                     0.2  Iris-setosa       13.20
# 39                     0.2  Iris-setosa       17.34
# 42                     0.2  Iris-setosa       14.08
# 46                     0.2  Iris-setosa       19.38
# 47                     0.2  Iris-setosa       14.72
# 33                     0.2  Iris-setosa       23.10
# 22                     0.2  Iris-setosa       16.56
# 24                     0.2  Iris-setosa       16.32
# 7                      0.2  Iris-setosa       17.00
# 1                      0.2  Iris-setosa       14.70
# 2                      0.2  Iris-setosa       15.04
# 3                      0.2  Iris-setosa       14.26
# 4                      0.2  Iris-setosa       18.00
# 8                      0.2  Iris-setosa       12.76
# 10                     0.2  Iris-setosa       19.98
# ...                    ...          ...         ...
# 120                    NaN          NaN         NaN
# 121                    NaN          NaN         NaN
# 122                    NaN          NaN         NaN
# 123                    NaN          NaN         NaN
# 124                    NaN          NaN         NaN
# 125                    NaN          NaN         NaN
# 126                    NaN          NaN         NaN
# 127                    NaN          NaN         NaN
# 128                    NaN          NaN         NaN
# 129                    NaN          NaN         NaN
# 130                    NaN          NaN         NaN
# 131                    NaN          NaN         NaN
# 132                    NaN          NaN         NaN
# 133                    NaN          NaN         NaN
# 134                    NaN          NaN         NaN
# 135                    NaN          NaN         NaN
# 136                    NaN          NaN         NaN
# 137                    NaN          NaN         NaN
# 138                    NaN          NaN         NaN
# 139                    NaN          NaN         NaN
# 140                    NaN          NaN         NaN
# 141                    NaN          NaN         NaN
# 142                    NaN          NaN         NaN
# 143                    NaN          NaN         NaN
# 144                    NaN          NaN         NaN
# 145                    NaN          NaN         NaN
# 146                    NaN          NaN         NaN
# 147                    NaN          NaN         NaN
# 148                    NaN          NaN         NaN
# 149                    NaN          NaN         NaN
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris.drop(columns = ['SepalExtra'])
# Out:
#        index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# index
# 0        0.0                   5.1                  3.5                   1.4
# 1        1.0                   4.9                  3.0                   1.4
# 2        2.0                   4.7                  3.2                   1.3
# 3        3.0                   4.6                  3.1                   1.5
# 4        4.0                   5.0                  3.6                   1.4
# 5        5.0                   5.4                  3.9                   1.7
# 6        6.0                   4.6                  3.4                   1.4
# 7        7.0                   5.0                  3.4                   1.5
# 8        8.0                   4.4                  2.9                   1.4
# 9        9.0                   4.9                  3.1                   1.5
# 10      10.0                   5.4                  3.7                   1.5
# 11      11.0                   4.8                  3.4                   1.6
# 12      12.0                   4.8                  3.0                   1.4
# 13      13.0                   4.3                  3.0                   1.1
# 14      14.0                   5.8                  4.0                   1.2
# 15      15.0                   5.7                  4.4                   1.5
# 16      16.0                   5.4                  3.9                   1.3
# 17      17.0                   5.1                  3.5                   1.4
# 18      18.0                   5.7                  3.8                   1.7
# 19      19.0                   5.1                  3.8                   1.5
# 20      20.0                   5.4                  3.4                   1.7
# 21      21.0                   5.1                  3.7                   1.5
# 22      22.0                   4.6                  3.6                   1.0
# 23      23.0                   5.1                  3.3                   1.7
# 24      24.0                   4.8                  3.4                   1.9
# 25      25.0                   5.0                  3.0                   1.6
# 26      26.0                   5.0                  3.4                   1.6
# 27      27.0                   5.2                  3.5                   1.5
# 28      28.0                   5.2                  3.4                   1.4
# 29      29.0                   4.7                  3.2                   1.6
# ...      ...                   ...                  ...                   ...
# 120      NaN                   NaN                  NaN                   NaN
# 121      NaN                   NaN                  NaN                   NaN
# 122      NaN                   NaN                  NaN                   NaN
# 123      NaN                   NaN                  NaN                   NaN
# 124      NaN                   NaN                  NaN                   NaN
# 125      NaN                   NaN                  NaN                   NaN
# 126      NaN                   NaN                  NaN                   NaN
# 127      NaN                   NaN                  NaN                   NaN
# 128      NaN                   NaN                  NaN                   NaN
# 129      NaN                   NaN                  NaN                   NaN
# 130      NaN                   NaN                  NaN                   NaN
# 131      NaN                   NaN                  NaN                   NaN
# 132      NaN                   NaN                  NaN                   NaN
# 133      NaN                   NaN                  NaN                   NaN
# 134      NaN                   NaN                  NaN                   NaN
# 135      NaN                   NaN                  NaN                   NaN
# 136      NaN                   NaN                  NaN                   NaN
# 137      NaN                   NaN                  NaN                   NaN
# 138      NaN                   NaN                  NaN                   NaN
# 139      NaN                   NaN                  NaN                   NaN
# 140      NaN                   NaN                  NaN                   NaN
# 141      NaN                   NaN                  NaN                   NaN
# 142      NaN                   NaN                  NaN                   NaN
# 143      NaN                   NaN                  NaN                   NaN
# 144      NaN                   NaN                  NaN                   NaN
# 145      NaN                   NaN                  NaN                   NaN
# 146      NaN                   NaN                  NaN                   NaN
# 147      NaN                   NaN                  NaN                   NaN
# 148      NaN                   NaN                  NaN                   NaN
# 149      NaN                   NaN                  NaN                   NaN
#
#        Petal width (in cm)        Class
# index
# 0                      0.2  Iris-setosa
# 1                      0.2  Iris-setosa
# 2                      0.2  Iris-setosa
# 3                      0.2  Iris-setosa
# 4                      0.2  Iris-setosa
# 5                      0.4  Iris-setosa
# 6                      0.3  Iris-setosa
# 7                      0.2  Iris-setosa
# 8                      0.2  Iris-setosa
# 9                      0.1  Iris-setosa
# 10                     0.2  Iris-setosa
# 11                     0.2  Iris-setosa
# 12                     0.1  Iris-setosa
# 13                     0.1  Iris-setosa
# 14                     0.2  Iris-setosa
# 15                     0.4  Iris-setosa
# 16                     0.4  Iris-setosa
# 17                     0.3  Iris-setosa
# 18                     0.3  Iris-setosa
# 19                     0.3  Iris-setosa
# 20                     0.2  Iris-setosa
# 21                     0.4  Iris-setosa
# 22                     0.2  Iris-setosa
# 23                     0.5  Iris-setosa
# 24                     0.2  Iris-setosa
# 25                     0.2  Iris-setosa
# 26                     0.4  Iris-setosa
# 27                     0.2  Iris-setosa
# 28                     0.2  Iris-setosa
# 29                     0.2  Iris-setosa
# ...                    ...          ...
# 120                    NaN          NaN
# 121                    NaN          NaN
# 122                    NaN          NaN
# 123                    NaN          NaN
# 124                    NaN          NaN
# 125                    NaN          NaN
# 126                    NaN          NaN
# 127                    NaN          NaN
# 128                    NaN          NaN
# 129                    NaN          NaN
# 130                    NaN          NaN
# 131                    NaN          NaN
# 132                    NaN          NaN
# 133                    NaN          NaN
# 134                    NaN          NaN
# 135                    NaN          NaN
# 136                    NaN          NaN
# 137                    NaN          NaN
# 138                    NaN          NaN
# 139                    NaN          NaN
# 140                    NaN          NaN
# 141                    NaN          NaN
# 142                    NaN          NaN
# 143                    NaN          NaN
# 144                    NaN          NaN
# 145                    NaN          NaN
# 146                    NaN          NaN
# 147                    NaN          NaN
# 148                    NaN          NaN
# 149                    NaN          NaN
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=Iris.iloc[0:10,0:4]

# %%
IrisSubset
# Out:
#        index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# index
# 0        0.0                   5.1                  3.5                   1.4
# 1        1.0                   4.9                  3.0                   1.4
# 2        2.0                   4.7                  3.2                   1.3
# 3        3.0                   4.6                  3.1                   1.5
# 4        4.0                   5.0                  3.6                   1.4
# 5        5.0                   5.4                  3.9                   1.7
# 6        6.0                   4.6                  3.4                   1.4
# 7        7.0                   5.0                  3.4                   1.5
# 8        8.0                   4.4                  2.9                   1.4
# 9        9.0                   4.9                  3.1                   1.5
